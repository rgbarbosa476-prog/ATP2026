# %%
print("Adivinha o número!")
print("Opção 1: Queres adivinhar um número?")
print("Opção 2: Queres que o computador adivinhe o teu número?")
print("Opção 3: Sair")
op = int(input("1, 2 ou 3? "))
if op == 1:
    import random
    n = random.randint(1,100)
    i = 1
    num = int(input("Escreve o número que pensas que o computador está a pensar! "))
    while n != num:
        i = i + 1
        if n > num:
            print("maior que " + str(num))
        else:
            print("menor que " + str(num))
        num = int(input("Escreve o número que pensas que o computador está a pensar! "))        
        
    print("O número que o computador pensou era:", n, "e você acertou em ", i , "tentativas!")
    

if op == 2:
    sup = 100
    inf = 0
    n = 0
    resposta = str()
    acertou = str("acertou")
    while resposta != str(acertou):
        n = n + 1
        x = int((sup + inf) / 2)
        resposta = input("O seu número é " + str(x) + "? ")
        if resposta == "maior":
            inf = x
            print("maior que " + str(x))
        elif resposta == "menor":
            sup = x
            print("menor que " + str(x))
        elif resposta != "acertou":
            print("Diga se é menor ou maior!")

    print("O número que pensou era:", x, "e o computador acertou em ", n , "tentativas!")

if op == 3:
    print("Até uma próxima")
# Out:
# Adivinha o número!
# Opção 1: Queres adivinhar um número?
# Opção 2: Queres que o computador adivinhe o teu número?
# Opção 3: Sair
# Diga se é menor ou maior!
# maior que 50
# menor que 75
# maior que 62
# O número que pensou era: 68 e o computador acertou em  5 tentativas!
